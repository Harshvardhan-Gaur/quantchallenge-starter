# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/quantc/train.csv
# /kaggle/input/quantc/test.csv

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Conv1D, BatchNormalization, Activation, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
train = pd.read_csv("/kaggle/input/quantc/train.csv")
test = pd.read_csv("/kaggle/input/quantc/test.csv")
class TCN_LSTM_Model:
    def __init__(self, sequence_length=20, tcn_filters=64, lstm_units=50, dropout_rate=0.2):
        self.sequence_length = sequence_length
        self.tcn_filters = tcn_filters
        self.lstm_units = lstm_units
        self.dropout_rate = dropout_rate
        self.model = None
        self.feature_scaler = StandardScaler()
        self.target_scaler = StandardScaler()
        self.feature_columns = ['A', 'B', 'D', 'F', 'I', 'K', 'L']
        self.target_column = 'Y2'
        self._train_tail = None  # will hold last `sequence_length` scaled rows of TRAIN features

    def create_tcn_block(self, inputs, filters, kernel_size, dilation_rate):
        conv1 = Conv1D(filters=filters, kernel_size=kernel_size, dilation_rate=dilation_rate,
                       padding='causal')(inputs)
        conv1 = BatchNormalization()(conv1)
        conv1 = Activation('relu')(conv1)
        conv1 = Dropout(self.dropout_rate)(conv1)

        conv2 = Conv1D(filters=filters, kernel_size=kernel_size, dilation_rate=dilation_rate,
                       padding='causal')(conv1)
        conv2 = BatchNormalization()(conv2)
        conv2 = Activation('relu')(conv2)
        conv2 = Dropout(self.dropout_rate)(conv2)

        if inputs.shape[-1] != filters:
            residual = Conv1D(filters=filters, kernel_size=1, padding='same')(inputs)
        else:
            residual = inputs

        output = Add()([conv2, residual])
        output = Activation('relu')(output)
        return output

    def build_model(self, n_features):
        inputs = Input(shape=(self.sequence_length, n_features))
        tcn = self.create_tcn_block(inputs, self.tcn_filters, kernel_size=3, dilation_rate=1)
        tcn = self.create_tcn_block(tcn,    self.tcn_filters, kernel_size=3, dilation_rate=2)
        tcn = self.create_tcn_block(tcn,    self.tcn_filters, kernel_size=3, dilation_rate=4)
        tcn = self.create_tcn_block(tcn,    self.tcn_filters, kernel_size=3, dilation_rate=8)

        lstm1 = LSTM(self.lstm_units, return_sequences=True, dropout=self.dropout_rate)(tcn)
        lstm2 = LSTM(self.lstm_units // 2, return_sequences=False, dropout=self.dropout_rate)(lstm1)

        dense1 = Dense(32, activation='relu')(lstm2)
        dense1 = Dropout(self.dropout_rate)(dense1)
        dense2 = Dense(16, activation='relu')(dense1)
        dense2 = Dropout(self.dropout_rate)(dense2)
        output = Dense(1, activation='linear')(dense2)

        self.model = Model(inputs=inputs, outputs=output)
        self.model.compile(optimizer=Adam(learning_rate=1e-3), loss='mse', metrics=['mae', 'mse'])
        return self.model

    def create_sequences(self, data, target=None, is_training=True):
        X_sequences, y_sequences = [], []
        for i in range(self.sequence_length, len(data)):
            X_sequences.append(data[i-self.sequence_length:i])
            if is_training and target is not None:
                y_sequences.append(target[i])
        X_sequences = np.array(X_sequences)
        if is_training and target is not None:
            y_sequences = np.array(y_sequences)
            return X_sequences, y_sequences
        return X_sequences

    def prepare_data(self, train_df, test_df=None):
        X_train = train_df[self.feature_columns].values
        y_train = train_df[self.target_column].values.reshape(-1, 1)

        # fit scalers ONLY on train
        X_train_scaled = self.feature_scaler.fit_transform(X_train)
        y_train_scaled = self.target_scaler.fit_transform(y_train)

        # store tail context to enable full-length test predictions
        if len(X_train_scaled) < self.sequence_length:
            raise ValueError("Train length must be >= sequence_length")
        self._train_tail = X_train_scaled[-self.sequence_length:].copy()

        X_train_seq, y_train_seq = self.create_sequences(
            X_train_scaled, y_train_scaled.flatten(), is_training=True
        )
        result = {'X_train': X_train_seq, 'y_train': y_train_seq}

        if test_df is not None:
            X_test = test_df[self.feature_columns].values
            X_test_scaled = self.feature_scaler.transform(X_test)

            # build a continuous stream using the train tail as context for the first test window
            concat = np.vstack([self._train_tail, X_test_scaled])
            X_concat_seq = self.create_sequences(concat, is_training=False)

            # the last len(test_df) sequences align 1:1 with test rows
            X_test_seq = X_concat_seq[-len(test_df):]
            result['X_test'] = X_test_seq

        return result

    def train(self, train_df, validation_split=0.2, epochs=100, batch_size=32, verbose=1):
        data = self.prepare_data(train_df)
        X_train, y_train = data['X_train'], data['y_train']

        n_features = len(self.feature_columns)
        self.build_model(n_features)

        if verbose:
            print("Model Architecture:")
            self.model.summary()

        # REMOVED EarlyStopping (you asked to train till the end)
        callbacks = [
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-7, verbose=1)
        ]

        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_split=validation_split,
            callbacks=callbacks,
            verbose=verbose
        )
        return history

    def predict(self, test_df):
        if self.model is None:
            raise ValueError("Model must be trained before making predictions")

        # use stored train-tail context to avoid dropping the first `sequence_length` test rows
        X_test = test_df[self.feature_columns].values
        X_test_scaled = self.feature_scaler.transform(X_test)

        if self._train_tail is None or self._train_tail.shape[0] != self.sequence_length:
            raise ValueError("Train context missing. Call train(...) first.")

        concat = np.vstack([self._train_tail, X_test_scaled])
        X_concat_seq = self.create_sequences(concat, is_training=False)
        X_test_seq = X_concat_seq[-len(test_df):]  # align 1:1 with test rows

        y_pred_scaled = self.model.predict(X_test_seq, verbose=0)
        y_pred = self.target_scaler.inverse_transform(y_pred_scaled).flatten()
        return y_pred

    def evaluate_model(self, train_df, plot_results=True):
        data = self.prepare_data(train_df)
        X_train, y_train = data['X_train'], data['y_train']

        y_pred_scaled = self.model.predict(X_train, verbose=0)
        y_pred = self.target_scaler.inverse_transform(y_pred_scaled).flatten()
        y_true = self.target_scaler.inverse_transform(y_train.reshape(-1, 1)).flatten()

        mse = mean_squared_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true, y_pred)

        print(f"Training Performance Metrics:")
        print(f"MSE: {mse:.4f}")
        print(f"MAE: {mae:.4f}")
        print(f"RMSE: {rmse:.4f}")
        print(f"R²: {r2:.4f}")

        if plot_results:
            import matplotlib.pyplot as plt
            plt.figure(figsize=(12, 8))

            plt.subplot(2, 2, 1)
            plt.scatter(y_true, y_pred, alpha=0.5)
            mn, mx = min(y_true.min(), y_pred.min()), max(y_true.max(), y_pred.max())
            plt.plot([mn, mx], [mn, mx], 'r--', lw=2)
            plt.xlabel('Actual Y1'); plt.ylabel('Predicted Y1'); plt.title(f'Actual vs Predicted (R² = {r2:.3f})')

            plt.subplot(2, 2, 2)
            nshow = min(200, len(y_true))
            plt.plot(y_true[:nshow], label='Actual', alpha=0.7)
            plt.plot(y_pred[:nshow], label='Predicted', alpha=0.7)
            plt.xlabel('Time Steps'); plt.ylabel('Y1 Values')
            plt.title(f'Time Series Comparison (First {nshow} points)'); plt.legend()

            plt.subplot(2, 2, 3)
            residuals = y_true - y_pred
            plt.scatter(y_pred, residuals, alpha=0.5)
            plt.axhline(y=0, color='r', linestyle='--')
            plt.xlabel('Predicted Y2'); plt.ylabel('Residuals'); plt.title('Residual Plot')

            plt.subplot(2, 2, 4)
            plt.hist(residuals, bins=50, alpha=0.7, edgecolor='black')
            plt.xlabel('Residuals'); plt.ylabel('Frequency'); plt.title('Residual Distribution')
            plt.tight_layout(); plt.show()

        return {'mse': mse, 'mae': mae, 'rmse': rmse, 'r2': r2, 'predictions': y_pred, 'actual': y_true}

    def plot_training_history(self, history):
        import matplotlib.pyplot as plt
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Model Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
        plt.subplot(1, 2, 2)
        plt.plot(history.history['mae'], label='Training MAE')
        plt.plot(history.history['val_mae'], label='Validation MAE')
        plt.title('Model MAE'); plt.xlabel('Epoch'); plt.ylabel('MAE'); plt.legend()
        plt.tight_layout(); plt.show()
tcn_lstm = TCN_LSTM_Model(sequence_length=20, tcn_filters=64, lstm_units=50, dropout_rate=0.2)

history = tcn_lstm.train(train_df=train, validation_split=0.2, epochs=100, batch_size=32, verbose=1)
tcn_lstm.plot_training_history(history)

evaluation_results = tcn_lstm.evaluate_model(train, plot_results=True)

# full-length test predictions, 1:1 with test rows
test_predictions = tcn_lstm.predict(test)
test['Y2_predicted'] = test_predictions
print(test_predictions.shape, test_predictions[:10])
# Out:
# I0000 00:00:1758517574.769634      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model Architecture:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 20, 7)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 20, 64)    │      1,408 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 20, 64)    │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 20, 64)    │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 20, 64)    │     12,352 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 20, 64)    │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 20, 64)    │        512 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 20, 64)    │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 20, 64)    │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 20, 64)    │     12,352 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 20, 64)    │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 20, 64)    │     12,352 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 20, 64)    │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 20, 64)    │          0 │ dropout_3[0][0],  │
# │                     │                   │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 20, 64)    │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 20, 64)    │     12,352 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 20, 64)    │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 20, 64)    │     12,352 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 20, 64)    │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 20, 64)    │          0 │ dropout_5[0][0],  │
# │                     │                   │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 20, 64)    │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 20, 64)    │     12,352 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 20, 64)    │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 20, 64)    │     12,352 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 20, 64)    │          0 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 20, 64)    │          0 │ dropout_7[0][0],  │
# │                     │                   │            │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 20, 64)    │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 20, 50)    │     23,000 │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 25)        │      7,600 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        832 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 32)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 16)        │        528 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 16)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         17 │ dropout_9[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 122,409 (478.16 KB)
#  Trainable params: 121,385 (474.16 KB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/100
# I0000 00:00:1758517590.036461      96 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 62s 23ms/step - loss: 0.6538 - mae: 0.4226 - mse: 0.6538 - val_loss: 1.4277 - val_mae: 0.5192 - val_mse: 1.4277 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5554 - mae: 0.3817 - mse: 0.5554 - val_loss: 1.4874 - val_mae: 0.5193 - val_mse: 1.4874 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5737 - mae: 0.3739 - mse: 0.5737 - val_loss: 1.4277 - val_mae: 0.5082 - val_mse: 1.4277 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5793 - mae: 0.3772 - mse: 0.5793 - val_loss: 1.3179 - val_mae: 0.4896 - val_mse: 1.3179 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5261 - mae: 0.3661 - mse: 0.5261 - val_loss: 1.3744 - val_mae: 0.4962 - val_mse: 1.3744 - learning_rate: 0.0010
# Epoch 6/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5596 - mae: 0.3707 - mse: 0.5596 - val_loss: 1.3240 - val_mae: 0.4923 - val_mse: 1.3240 - learning_rate: 0.0010
# Epoch 7/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5475 - mae: 0.3707 - mse: 0.5475 - val_loss: 1.2949 - val_mae: 0.4849 - val_mse: 1.2949 - learning_rate: 0.0010
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.5246 - mae: 0.3652 - mse: 0.5246 - val_loss: 1.3643 - val_mae: 0.4957 - val_mse: 1.3643 - learning_rate: 0.0010
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5103 - mae: 0.3615 - mse: 0.5103 - val_loss: 1.2924 - val_mae: 0.4836 - val_mse: 1.2924 - learning_rate: 0.0010
# Epoch 10/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5378 - mae: 0.3679 - mse: 0.5378 - val_loss: 1.2464 - val_mae: 0.4843 - val_mse: 1.2464 - learning_rate: 0.0010
# Epoch 11/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4920 - mae: 0.3593 - mse: 0.4920 - val_loss: 1.4410 - val_mae: 0.5087 - val_mse: 1.4410 - learning_rate: 0.0010
# Epoch 12/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5221 - mae: 0.3629 - mse: 0.5221 - val_loss: 1.3291 - val_mae: 0.4929 - val_mse: 1.3291 - learning_rate: 0.0010
# Epoch 13/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4925 - mae: 0.3627 - mse: 0.4925 - val_loss: 1.2277 - val_mae: 0.4834 - val_mse: 1.2277 - learning_rate: 0.0010
# Epoch 14/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4961 - mae: 0.3619 - mse: 0.4961 - val_loss: 1.3018 - val_mae: 0.4877 - val_mse: 1.3018 - learning_rate: 0.0010
# Epoch 15/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4998 - mae: 0.3624 - mse: 0.4998 - val_loss: 1.3912 - val_mae: 0.5005 - val_mse: 1.3912 - learning_rate: 0.0010
# Epoch 16/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5066 - mae: 0.3576 - mse: 0.5066 - val_loss: 1.4574 - val_mae: 0.5168 - val_mse: 1.4574 - learning_rate: 0.0010
# Epoch 17/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5365 - mae: 0.3691 - mse: 0.5365 - val_loss: 1.3520 - val_mae: 0.4965 - val_mse: 1.3520 - learning_rate: 0.0010
# Epoch 18/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5123 - mae: 0.3609 - mse: 0.5123 - val_loss: 1.3418 - val_mae: 0.4949 - val_mse: 1.3418 - learning_rate: 0.0010
# Epoch 19/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4798 - mae: 0.3570 - mse: 0.4798 - val_loss: 1.4351 - val_mae: 0.5109 - val_mse: 1.4351 - learning_rate: 0.0010
# Epoch 20/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.5393 - mae: 0.3671 - mse: 0.5393 - val_loss: 1.3989 - val_mae: 0.5044 - val_mse: 1.3989 - learning_rate: 0.0010
# Epoch 21/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5120 - mae: 0.3637 - mse: 0.5120
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.5120 - mae: 0.3637 - mse: 0.5120 - val_loss: 1.4772 - val_mae: 0.5233 - val_mse: 1.4772 - learning_rate: 0.0010
# Epoch 22/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4897 - mae: 0.3573 - mse: 0.4897 - val_loss: 1.3278 - val_mae: 0.4939 - val_mse: 1.3278 - learning_rate: 5.0000e-04
# Epoch 23/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4766 - mae: 0.3544 - mse: 0.4766 - val_loss: 1.4245 - val_mae: 0.5055 - val_mse: 1.4245 - learning_rate: 5.0000e-04
# Epoch 24/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4749 - mae: 0.3543 - mse: 0.4749 - val_loss: 1.3683 - val_mae: 0.4984 - val_mse: 1.3683 - learning_rate: 5.0000e-04
# Epoch 25/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4842 - mae: 0.3538 - mse: 0.4842 - val_loss: 1.3792 - val_mae: 0.5005 - val_mse: 1.3792 - learning_rate: 5.0000e-04
# Epoch 26/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4668 - mae: 0.3515 - mse: 0.4668 - val_loss: 1.3884 - val_mae: 0.5050 - val_mse: 1.3884 - learning_rate: 5.0000e-04
# Epoch 27/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4825 - mae: 0.3542 - mse: 0.4825 - val_loss: 1.3742 - val_mae: 0.5020 - val_mse: 1.3742 - learning_rate: 5.0000e-04
# Epoch 28/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4462 - mae: 0.3510 - mse: 0.4462 - val_loss: 1.4386 - val_mae: 0.5127 - val_mse: 1.4386 - learning_rate: 5.0000e-04
# Epoch 29/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4539 - mae: 0.3540 - mse: 0.4539
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4539 - mae: 0.3540 - mse: 0.4539 - val_loss: 1.3351 - val_mae: 0.4943 - val_mse: 1.3351 - learning_rate: 5.0000e-04
# Epoch 30/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4693 - mae: 0.3563 - mse: 0.4693 - val_loss: 1.4149 - val_mae: 0.5042 - val_mse: 1.4149 - learning_rate: 2.5000e-04
# Epoch 31/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4787 - mae: 0.3506 - mse: 0.4787 - val_loss: 1.4053 - val_mae: 0.5008 - val_mse: 1.4053 - learning_rate: 2.5000e-04
# Epoch 32/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4531 - mae: 0.3486 - mse: 0.4531 - val_loss: 1.4034 - val_mae: 0.5031 - val_mse: 1.4034 - learning_rate: 2.5000e-04
# Epoch 33/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4461 - mae: 0.3464 - mse: 0.4461 - val_loss: 1.3812 - val_mae: 0.5047 - val_mse: 1.3812 - learning_rate: 2.5000e-04
# Epoch 34/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4264 - mae: 0.3424 - mse: 0.4264 - val_loss: 1.4119 - val_mae: 0.5065 - val_mse: 1.4119 - learning_rate: 2.5000e-04
# Epoch 35/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4555 - mae: 0.3461 - mse: 0.4555 - val_loss: 1.3521 - val_mae: 0.4964 - val_mse: 1.3521 - learning_rate: 2.5000e-04
# Epoch 36/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4329 - mae: 0.3448 - mse: 0.4329 - val_loss: 1.4022 - val_mae: 0.5044 - val_mse: 1.4022 - learning_rate: 2.5000e-04
# Epoch 37/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4378 - mae: 0.3425 - mse: 0.4378
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4378 - mae: 0.3425 - mse: 0.4378 - val_loss: 1.3311 - val_mae: 0.4932 - val_mse: 1.3311 - learning_rate: 2.5000e-04
# Epoch 38/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4392 - mae: 0.3476 - mse: 0.4392 - val_loss: 1.3514 - val_mae: 0.4956 - val_mse: 1.3514 - learning_rate: 1.2500e-04
# Epoch 39/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4138 - mae: 0.3407 - mse: 0.4138 - val_loss: 1.3594 - val_mae: 0.4953 - val_mse: 1.3594 - learning_rate: 1.2500e-04
# Epoch 40/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4531 - mae: 0.3432 - mse: 0.4531 - val_loss: 1.3508 - val_mae: 0.4978 - val_mse: 1.3508 - learning_rate: 1.2500e-04
# Epoch 41/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4307 - mae: 0.3444 - mse: 0.4307 - val_loss: 1.4136 - val_mae: 0.5030 - val_mse: 1.4136 - learning_rate: 1.2500e-04
# Epoch 42/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4325 - mae: 0.3472 - mse: 0.4325 - val_loss: 1.3559 - val_mae: 0.5009 - val_mse: 1.3559 - learning_rate: 1.2500e-04
# Epoch 43/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4168 - mae: 0.3442 - mse: 0.4168 - val_loss: 1.3664 - val_mae: 0.4981 - val_mse: 1.3664 - learning_rate: 1.2500e-04
# Epoch 44/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4207 - mae: 0.3424 - mse: 0.4207 - val_loss: 1.3644 - val_mae: 0.4997 - val_mse: 1.3644 - learning_rate: 1.2500e-04
# Epoch 45/100
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4258 - mae: 0.3418 - mse: 0.4258
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - loss: 0.4258 - mae: 0.3418 - mse: 0.4258 - val_loss: 1.3799 - val_mae: 0.5035 - val_mse: 1.3799 - learning_rate: 1.2500e-04
# Epoch 46/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4185 - mae: 0.3415 - mse: 0.4185 - val_loss: 1.3540 - val_mae: 0.4998 - val_mse: 1.3540 - learning_rate: 6.2500e-05
# Epoch 47/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4292 - mae: 0.3467 - mse: 0.4292 - val_loss: 1.3731 - val_mae: 0.5024 - val_mse: 1.3731 - learning_rate: 6.2500e-05
# Epoch 48/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - loss: 0.4434 - mae: 0.3438 - mse: 0.4434 - val_loss: 1.3864 - val_mae: 0.5007 - val_mse: 1.3864 - learning_rate: 6.2500e-05
# Epoch 49/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4508 - mae: 0.3435 - mse: 0.4508 - val_loss: 1.3808 - val_mae: 0.4993 - val_mse: 1.3808 - learning_rate: 6.2500e-05
# Epoch 50/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.4529 - mae: 0.3504 - mse: 0.4529 - val_loss: 1.3930 - val_mae: 0.5007 - val_mse: 1.3930 - learning_rate: 6.2500e-05
# Epoch 51/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.4352 - mae: 0.3426 - mse: 0.4352 - val_loss: 1.3687 - val_mae: 0.5006 - val_mse: 1.3687 - learning_rate: 6.2500e-05
# Epoch 52/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4441 - mae: 0.3465 - mse: 0.4441 - val_loss: 1.3827 - val_mae: 0.5030 - val_mse: 1.3827 - learning_rate: 6.2500e-05
# Epoch 53/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4231 - mae: 0.3431 - mse: 0.4231
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4231 - mae: 0.3431 - mse: 0.4231 - val_loss: 1.3884 - val_mae: 0.5034 - val_mse: 1.3884 - learning_rate: 6.2500e-05
# Epoch 54/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - loss: 0.4362 - mae: 0.3423 - mse: 0.4362 - val_loss: 1.3889 - val_mae: 0.5024 - val_mse: 1.3889 - learning_rate: 3.1250e-05
# Epoch 55/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4107 - mae: 0.3397 - mse: 0.4107 - val_loss: 1.3790 - val_mae: 0.5000 - val_mse: 1.3790 - learning_rate: 3.1250e-05
# Epoch 56/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - loss: 0.4413 - mae: 0.3439 - mse: 0.4413 - val_loss: 1.3857 - val_mae: 0.5039 - val_mse: 1.3857 - learning_rate: 3.1250e-05
# Epoch 57/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4293 - mae: 0.3417 - mse: 0.4293 - val_loss: 1.4049 - val_mae: 0.5034 - val_mse: 1.4049 - learning_rate: 3.1250e-05
# Epoch 58/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4382 - mae: 0.3447 - mse: 0.4382 - val_loss: 1.3833 - val_mae: 0.5009 - val_mse: 1.3833 - learning_rate: 3.1250e-05
# Epoch 59/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4158 - mae: 0.3396 - mse: 0.4158 - val_loss: 1.3803 - val_mae: 0.5006 - val_mse: 1.3803 - learning_rate: 3.1250e-05
# Epoch 60/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4538 - mae: 0.3452 - mse: 0.4538 - val_loss: 1.3962 - val_mae: 0.5018 - val_mse: 1.3962 - learning_rate: 3.1250e-05
# Epoch 61/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4539 - mae: 0.3448 - mse: 0.4539
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4539 - mae: 0.3448 - mse: 0.4539 - val_loss: 1.3839 - val_mae: 0.5012 - val_mse: 1.3839 - learning_rate: 3.1250e-05
# Epoch 62/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 0.4367 - mae: 0.3437 - mse: 0.4367 - val_loss: 1.3878 - val_mae: 0.5012 - val_mse: 1.3878 - learning_rate: 1.5625e-05
# Epoch 63/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4217 - mae: 0.3401 - mse: 0.4217 - val_loss: 1.3914 - val_mae: 0.5025 - val_mse: 1.3914 - learning_rate: 1.5625e-05
# Epoch 64/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4623 - mae: 0.3459 - mse: 0.4623 - val_loss: 1.3837 - val_mae: 0.5008 - val_mse: 1.3837 - learning_rate: 1.5625e-05
# Epoch 65/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4258 - mae: 0.3452 - mse: 0.4258 - val_loss: 1.3964 - val_mae: 0.5017 - val_mse: 1.3964 - learning_rate: 1.5625e-05
# Epoch 66/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4116 - mae: 0.3394 - mse: 0.4116 - val_loss: 1.3912 - val_mae: 0.5011 - val_mse: 1.3912 - learning_rate: 1.5625e-05
# Epoch 67/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4200 - mae: 0.3439 - mse: 0.4200 - val_loss: 1.3729 - val_mae: 0.5003 - val_mse: 1.3729 - learning_rate: 1.5625e-05
# Epoch 68/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4290 - mae: 0.3436 - mse: 0.4290 - val_loss: 1.3919 - val_mae: 0.5021 - val_mse: 1.3919 - learning_rate: 1.5625e-05
# Epoch 69/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4552 - mae: 0.3468 - mse: 0.4552
# Epoch 69: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4551 - mae: 0.3468 - mse: 0.4551 - val_loss: 1.3942 - val_mae: 0.5024 - val_mse: 1.3942 - learning_rate: 1.5625e-05
# Epoch 70/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4152 - mae: 0.3397 - mse: 0.4152 - val_loss: 1.4123 - val_mae: 0.5028 - val_mse: 1.4123 - learning_rate: 7.8125e-06
# Epoch 71/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4272 - mae: 0.3420 - mse: 0.4272 - val_loss: 1.3844 - val_mae: 0.5015 - val_mse: 1.3844 - learning_rate: 7.8125e-06
# Epoch 72/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4084 - mae: 0.3402 - mse: 0.4084 - val_loss: 1.3820 - val_mae: 0.5016 - val_mse: 1.3820 - learning_rate: 7.8125e-06
# Epoch 73/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4238 - mae: 0.3437 - mse: 0.4238 - val_loss: 1.3859 - val_mae: 0.5019 - val_mse: 1.3859 - learning_rate: 7.8125e-06
# Epoch 74/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4211 - mae: 0.3428 - mse: 0.4211 - val_loss: 1.3766 - val_mae: 0.5018 - val_mse: 1.3766 - learning_rate: 7.8125e-06
# Epoch 75/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4127 - mae: 0.3438 - mse: 0.4127 - val_loss: 1.3830 - val_mae: 0.5017 - val_mse: 1.3830 - learning_rate: 7.8125e-06
# Epoch 76/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4373 - mae: 0.3422 - mse: 0.4373 - val_loss: 1.3814 - val_mae: 0.5019 - val_mse: 1.3814 - learning_rate: 7.8125e-06
# Epoch 77/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4399 - mae: 0.3412 - mse: 0.4399
# Epoch 77: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4399 - mae: 0.3412 - mse: 0.4399 - val_loss: 1.4017 - val_mae: 0.5026 - val_mse: 1.4017 - learning_rate: 7.8125e-06
# Epoch 78/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4501 - mae: 0.3450 - mse: 0.4501 - val_loss: 1.3831 - val_mae: 0.5017 - val_mse: 1.3831 - learning_rate: 3.9063e-06
# Epoch 79/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4233 - mae: 0.3433 - mse: 0.4233 - val_loss: 1.3902 - val_mae: 0.5033 - val_mse: 1.3902 - learning_rate: 3.9063e-06
# Epoch 80/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4114 - mae: 0.3419 - mse: 0.4114 - val_loss: 1.3952 - val_mae: 0.5023 - val_mse: 1.3952 - learning_rate: 3.9063e-06
# Epoch 81/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4430 - mae: 0.3468 - mse: 0.4430 - val_loss: 1.4048 - val_mae: 0.5026 - val_mse: 1.4048 - learning_rate: 3.9063e-06
# Epoch 82/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4320 - mae: 0.3411 - mse: 0.4320 - val_loss: 1.3943 - val_mae: 0.5037 - val_mse: 1.3943 - learning_rate: 3.9063e-06
# Epoch 83/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4083 - mae: 0.3392 - mse: 0.4083 - val_loss: 1.4055 - val_mae: 0.5029 - val_mse: 1.4055 - learning_rate: 3.9063e-06
# Epoch 84/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4075 - mae: 0.3409 - mse: 0.4075 - val_loss: 1.3900 - val_mae: 0.5024 - val_mse: 1.3900 - learning_rate: 3.9063e-06
# Epoch 85/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4504 - mae: 0.3463 - mse: 0.4504
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4504 - mae: 0.3463 - mse: 0.4504 - val_loss: 1.4099 - val_mae: 0.5030 - val_mse: 1.4099 - learning_rate: 3.9063e-06
# Epoch 86/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4176 - mae: 0.3412 - mse: 0.4176 - val_loss: 1.3834 - val_mae: 0.5038 - val_mse: 1.3834 - learning_rate: 1.9531e-06
# Epoch 87/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4512 - mae: 0.3441 - mse: 0.4512 - val_loss: 1.3834 - val_mae: 0.5023 - val_mse: 1.3834 - learning_rate: 1.9531e-06
# Epoch 88/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4166 - mae: 0.3384 - mse: 0.4166 - val_loss: 1.3656 - val_mae: 0.5013 - val_mse: 1.3656 - learning_rate: 1.9531e-06
# Epoch 89/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4588 - mae: 0.3448 - mse: 0.4588 - val_loss: 1.3906 - val_mae: 0.5028 - val_mse: 1.3906 - learning_rate: 1.9531e-06
# Epoch 90/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.4180 - mae: 0.3394 - mse: 0.4180 - val_loss: 1.3893 - val_mae: 0.5024 - val_mse: 1.3893 - learning_rate: 1.9531e-06
# Epoch 91/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - loss: 0.4198 - mae: 0.3390 - mse: 0.4198 - val_loss: 1.3775 - val_mae: 0.5021 - val_mse: 1.3775 - learning_rate: 1.9531e-06
# Epoch 92/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4313 - mae: 0.3442 - mse: 0.4313 - val_loss: 1.3925 - val_mae: 0.5028 - val_mse: 1.3925 - learning_rate: 1.9531e-06
# Epoch 93/100
# 1998/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4075 - mae: 0.3396 - mse: 0.4075
# Epoch 93: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4075 - mae: 0.3396 - mse: 0.4075 - val_loss: 1.3913 - val_mae: 0.5020 - val_mse: 1.3913 - learning_rate: 1.9531e-06
# Epoch 94/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4473 - mae: 0.3439 - mse: 0.4473 - val_loss: 1.3836 - val_mae: 0.5029 - val_mse: 1.3836 - learning_rate: 9.7656e-07
# Epoch 95/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4135 - mae: 0.3402 - mse: 0.4135 - val_loss: 1.3817 - val_mae: 0.5026 - val_mse: 1.3817 - learning_rate: 9.7656e-07
# Epoch 96/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4151 - mae: 0.3390 - mse: 0.4151 - val_loss: 1.3815 - val_mae: 0.5030 - val_mse: 1.3815 - learning_rate: 9.7656e-07
# Epoch 97/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4181 - mae: 0.3417 - mse: 0.4181 - val_loss: 1.3782 - val_mae: 0.5008 - val_mse: 1.3782 - learning_rate: 9.7656e-07
# Epoch 98/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4317 - mae: 0.3435 - mse: 0.4317 - val_loss: 1.3837 - val_mae: 0.5015 - val_mse: 1.3837 - learning_rate: 9.7656e-07
# Epoch 99/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4224 - mae: 0.3417 - mse: 0.4224 - val_loss: 1.3892 - val_mae: 0.5010 - val_mse: 1.3892 - learning_rate: 9.7656e-07
# Epoch 100/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.4283 - mae: 0.3423 - mse: 0.4283 - val_loss: 1.3774 - val_mae: 0.5012 - val_mse: 1.3774 - learning_rate: 9.7656e-07
# Training Performance Metrics:
# MSE: 0.5068
# MAE: 0.3544
# RMSE: 0.7119
# R²: 0.4061
# (15996,) [-0.19773501 -0.31791633 -0.3068308  -0.3300665  -0.2656154  -0.2944584
#  -0.1639769  -0.16849713 -0.27060595 -0.19968563]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Conv1D, BatchNormalization, Activation, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Load data
train = pd.read_csv("/kaggle/input/quantc/train.csv")
test = pd.read_csv("/kaggle/input/quantc/test.csv")

class TCN_LSTM_Model:
    def __init__(self, sequence_length=20, tcn_filters=64, lstm_units=50, dropout_rate=0.2):
        self.sequence_length = sequence_length
        self.tcn_filters = tcn_filters
        self.lstm_units = lstm_units
        self.dropout_rate = dropout_rate
        self.model = None
        self.feature_scaler = StandardScaler()
        self.target_scaler = StandardScaler()
        self.feature_columns = ['A', 'B', 'D', 'F', 'I', 'K', 'L']
        self.target_column = 'Y2'
        self._train_tail = None

    def create_tcn_block(self, inputs, filters, kernel_size, dilation_rate):
        """Fixed TCN block with proper residual connections"""
        conv1 = Conv1D(filters=filters, kernel_size=kernel_size, dilation_rate=dilation_rate,
                       padding='causal')(inputs)
        conv1 = BatchNormalization()(conv1)
        conv1 = Activation('relu')(conv1)
        conv1 = Dropout(self.dropout_rate)(conv1)

        conv2 = Conv1D(filters=filters, kernel_size=kernel_size, dilation_rate=dilation_rate,
                       padding='causal')(conv1)
        conv2 = BatchNormalization()(conv2)
        
        # FIXED: Proper residual connection handling
        if inputs.shape[-1] != filters:
            residual = Conv1D(filters=filters, kernel_size=1, padding='same')(inputs)
        else:
            residual = inputs

        # Add residual connection BEFORE final activation
        output = Add()([conv2, residual])
        output = Activation('relu')(output)
        
        return output

    def build_model(self, n_features):
        """Fixed model architecture with proper regularization"""
        inputs = Input(shape=(self.sequence_length, n_features))
        
        # FIXED: More appropriate TCN architecture
        tcn = self.create_tcn_block(inputs, self.tcn_filters, kernel_size=3, dilation_rate=1)
        tcn = self.create_tcn_block(tcn, self.tcn_filters, kernel_size=3, dilation_rate=2)
        tcn = self.create_tcn_block(tcn, self.tcn_filters, kernel_size=3, dilation_rate=4)
        # FIXED: Removed excessive dilation that might cause vanishing gradients
        
        # FIXED: Better LSTM configuration
        lstm1 = LSTM(self.lstm_units, return_sequences=True, 
                    dropout=self.dropout_rate, recurrent_dropout=0.1)(tcn)
        lstm2 = LSTM(self.lstm_units // 2, return_sequences=False, 
                    dropout=self.dropout_rate, recurrent_dropout=0.1)(lstm1)

        # FIXED: Improved dense layers with batch normalization
        dense1 = Dense(32, activation='relu')(lstm2)
        dense1 = BatchNormalization()(dense1)
        dense1 = Dropout(self.dropout_rate)(dense1)
        
        dense2 = Dense(16, activation='relu')(dense1)
        dense2 = BatchNormalization()(dense2)
        dense2 = Dropout(self.dropout_rate)(dense2)
        
        output = Dense(1, activation='linear')(dense2)

        self.model = Model(inputs=inputs, outputs=output)
        
        # FIXED: Better optimizer settings with gradient clipping
        optimizer = Adam(learning_rate=1e-3, clipnorm=1.0)
        self.model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
        return self.model

    def create_sequences(self, data, target=None, is_training=True):
        """FIXED: Proper sequence creation with validation"""
        if len(data) < self.sequence_length:
            raise ValueError(f"Data length ({len(data)}) must be >= sequence_length ({self.sequence_length})")
            
        X_sequences, y_sequences = [], []
        for i in range(self.sequence_length, len(data)):
            X_sequences.append(data[i-self.sequence_length:i])
            if is_training and target is not None:
                y_sequences.append(target[i])
        
        X_sequences = np.array(X_sequences)
        if is_training and target is not None:
            y_sequences = np.array(y_sequences)
            return X_sequences, y_sequences
        return X_sequences

    def prepare_data(self, train_df, test_df=None):
        """FIXED: Better data preparation with validation"""
        # Check for missing values
        if train_df[self.feature_columns + [self.target_column]].isnull().any().any():
            print("Warning: Missing values detected in training data")
            train_df = train_df.dropna(subset=self.feature_columns + [self.target_column])
        
        X_train = train_df[self.feature_columns].values
        y_train = train_df[self.target_column].values.reshape(-1, 1)

        # FIXED: Fit scalers only on training data
        X_train_scaled = self.feature_scaler.fit_transform(X_train)
        y_train_scaled = self.target_scaler.fit_transform(y_train)

        # Store train tail for test predictions
        if len(X_train_scaled) < self.sequence_length:
            raise ValueError(f"Train length ({len(X_train_scaled)}) must be >= sequence_length ({self.sequence_length})")
        
        self._train_tail = X_train_scaled[-self.sequence_length:].copy()

        X_train_seq, y_train_seq = self.create_sequences(
            X_train_scaled, y_train_scaled.flatten(), is_training=True
        )
        
        result = {'X_train': X_train_seq, 'y_train': y_train_seq}

        if test_df is not None:
            # Check test data
            if test_df[self.feature_columns].isnull().any().any():
                print("Warning: Missing values detected in test data")
                # For test data, you might want to fill missing values instead of dropping
                test_df = test_df.fillna(method='ffill').fillna(method='bfill')
            
            X_test = test_df[self.feature_columns].values
            X_test_scaled = self.feature_scaler.transform(X_test)

            # FIXED: Better handling of test sequences
            concat = np.vstack([self._train_tail, X_test_scaled])
            X_concat_seq = self.create_sequences(concat, is_training=False)

            # Ensure we have the right number of test sequences
            if len(X_concat_seq) < len(test_df):
                raise ValueError("Not enough sequences generated for test data")
            
            X_test_seq = X_concat_seq[-len(test_df):]
            result['X_test'] = X_test_seq

        return result

    def train(self, train_df, validation_split=0.2, epochs=100, batch_size=32, verbose=1):
        """FIXED: Better training with early stopping option"""
        data = self.prepare_data(train_df)
        X_train, y_train = data['X_train'], data['y_train']

        n_features = len(self.feature_columns)
        self.build_model(n_features)

        if verbose:
            print("Model Architecture:")
            self.model.summary()

        # FIXED: Added early stopping back as an option with patience
        callbacks = [
         
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-7, verbose=1)
        ]

        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_split=validation_split,
            callbacks=callbacks,
            verbose=verbose,
            shuffle=True  # FIXED: Added shuffling for better training
        )
        return history

    def predict(self, test_df):
        """FIXED: Better prediction with validation"""
        if self.model is None:
            raise ValueError("Model must be trained before making predictions")

        if self._train_tail is None:
            raise ValueError("Train context missing. Call train(...) first.")

        X_test = test_df[self.feature_columns].values
        X_test_scaled = self.feature_scaler.transform(X_test)

        concat = np.vstack([self._train_tail, X_test_scaled])
        X_concat_seq = self.create_sequences(concat, is_training=False)
        
        if len(X_concat_seq) < len(test_df):
            raise ValueError(f"Generated {len(X_concat_seq)} sequences but need {len(test_df)}")
            
        X_test_seq = X_concat_seq[-len(test_df):]

        y_pred_scaled = self.model.predict(X_test_seq, verbose=0)
        y_pred = self.target_scaler.inverse_transform(y_pred_scaled).flatten()
        return y_pred

    def evaluate_model(self, train_df, plot_results=True):
        """FIXED: Better evaluation with proper metrics calculation"""
        # Use same data preparation as training
        data = self.prepare_data(train_df)
        X_train, y_train = data['X_train'], data['y_train']

        y_pred_scaled = self.model.predict(X_train, verbose=0)
        y_pred = self.target_scaler.inverse_transform(y_pred_scaled).flatten()
        y_true = self.target_scaler.inverse_transform(y_train.reshape(-1, 1)).flatten()

        # FIXED: Added more robust metrics
        mse = mean_squared_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true, y_pred)
        
        # Additional metrics
        mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
        
        print(f"Training Performance Metrics:")
        print(f"MSE: {mse:.4f}")
        print(f"MAE: {mae:.4f}")
        print(f"RMSE: {rmse:.4f}")
        print(f"R²: {r2:.4f}")
        print(f"MAPE: {mape:.2f}%")

        if plot_results:
            plt.figure(figsize=(15, 10))

            plt.subplot(2, 3, 1)
            plt.scatter(y_true, y_pred, alpha=0.5)
            mn, mx = min(y_true.min(), y_pred.min()), max(y_true.max(), y_pred.max())
            plt.plot([mn, mx], [mn, mx], 'r--', lw=2)
            plt.xlabel('Actual Y2')
            plt.ylabel('Predicted Y2')
            plt.title(f'Actual vs Predicted (R² = {r2:.3f})')

            plt.subplot(2, 3, 2)
            nshow = min(200, len(y_true))
            plt.plot(y_true[:nshow], label='Actual', alpha=0.7)
            plt.plot(y_pred[:nshow], label='Predicted', alpha=0.7)
            plt.xlabel('Time Steps')
            plt.ylabel('Y2 Values')
            plt.title(f'Time Series Comparison (First {nshow} points)')
            plt.legend()

            plt.subplot(2, 3, 3)
            residuals = y_true - y_pred
            plt.scatter(y_pred, residuals, alpha=0.5)
            plt.axhline(y=0, color='r', linestyle='--')
            plt.xlabel('Predicted Y1')
            plt.ylabel('Residuals')
            plt.title('Residual Plot')

            plt.subplot(2, 3, 4)
            plt.hist(residuals, bins=50, alpha=0.7, edgecolor='black')
            plt.xlabel('Residuals')
            plt.ylabel('Frequency')
            plt.title('Residual Distribution')

            # FIXED: Added additional diagnostic plots
            plt.subplot(2, 3, 5)
            plt.plot(np.abs(residuals))
            plt.xlabel('Sample Index')
            plt.ylabel('Absolute Error')
            plt.title('Absolute Error Over Time')

            plt.subplot(2, 3, 6)
            from scipy import stats
            stats.probplot(residuals, dist="norm", plot=plt)
            plt.title('Q-Q Plot')
            
            plt.tight_layout()
            plt.show()

        return {
            'mse': mse, 'mae': mae, 'rmse': rmse, 'r2': r2, 'mape': mape,
            'predictions': y_pred, 'actual': y_true
        }

    def plot_training_history(self, history):
        """FIXED: Better training history visualization"""
        plt.figure(figsize=(15, 5))
        
        plt.subplot(1, 3, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Model Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.yscale('log')  # FIXED: Log scale for better visualization

        plt.subplot(1, 3, 2)
        plt.plot(history.history['mae'], label='Training MAE')
        plt.plot(history.history['val_mae'], label='Validation MAE')
        plt.title('Model MAE')
        plt.xlabel('Epoch')
        plt.ylabel('MAE')
        plt.legend()

        # FIXED: Added learning rate plot if available
        plt.subplot(1, 3, 3)
        if 'lr' in history.history:
            plt.plot(history.history['lr'])
            plt.title('Learning Rate')
            plt.xlabel('Epoch')
            plt.ylabel('Learning Rate')
            plt.yscale('log')
        else:
            # Show validation loss zoomed in
            val_loss = history.history['val_loss']
            plt.plot(val_loss[10:])  # Skip first 10 epochs
            plt.title('Validation Loss (Epochs 10+)')
            plt.xlabel('Epoch')
            plt.ylabel('Validation Loss')
        
        plt.tight_layout()
        plt.show()

# FIXED: Usage with better error handling
try:
    tcn_lstm = TCN_LSTM_Model(sequence_length=20, tcn_filters=64, lstm_units=50, dropout_rate=0.2)
    
    print(f"Training data shape: {train.shape}")
    print(f"Test data shape: {test.shape}")
    print(f"Feature columns: {tcn_lstm.feature_columns}")
    print(f"Target column: {tcn_lstm.target_column}")
    
    # Check if all required columns exist
    missing_features = set(tcn_lstm.feature_columns) - set(train.columns)
    if missing_features:
        raise ValueError(f"Missing feature columns in training data: {missing_features}")
    
    if tcn_lstm.target_column not in train.columns:
        raise ValueError(f"Target column '{tcn_lstm.target_column}' not found in training data")

    history = tcn_lstm.train(train_df=train, validation_split=0.2, epochs=100, batch_size=32, verbose=1)
    tcn_lstm.plot_training_history(history)

    evaluation_results = tcn_lstm.evaluate_model(train, plot_results=True)

    # Generate test predictions
    test_predictions = tcn_lstm.predict(test)
    test['Y2_predicted'] = test_predictions
    
    print(f"\nTest predictions generated successfully!")
    print(f"Predictions shape: {test_predictions.shape}")
    print(f"First 10 predictions: {test_predictions[:10]}")
    print(f"Prediction statistics:")
    print(f"  Mean: {test_predictions.mean():.4f}")
    print(f"  Std: {test_predictions.std():.4f}")
    print(f"  Min: {test_predictions.min():.4f}")
    print(f"  Max: {test_predictions.max():.4f}")
    
except Exception as e:
    print(f"Error occurred: {str(e)}")
    print("Please check your data and model configuration.")
# Out:
# Training data shape: (80000, 17)
# Test data shape: (15996, 16)
# Feature columns: ['A', 'B', 'D', 'F', 'I', 'K', 'L']
# Target column: Y2
# Model Architecture:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 20, 7)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 20, 64)    │      1,408 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 20, 64)    │          0 │ activation_18[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 20, 64)    │     12,352 │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 20, 64)    │        512 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │                     │                   │            │ conv1d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 20, 64)    │          0 │ add_7[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 20, 64)    │     12,352 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 20, 64)    │          0 │ activation_20[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 20, 64)    │     12,352 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 20, 64)    │          0 │ add_8[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 20, 64)    │     12,352 │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_21[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 20, 64)    │          0 │ activation_22[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 20, 64)    │     12,352 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 64)    │        256 │ conv1d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 20, 64)    │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 20, 64)    │          0 │ add_9[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_4 (LSTM)       │ (None, 20, 50)    │     23,000 │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_5 (LSTM)       │ (None, 25)        │      7,600 │ lstm_4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 32)        │        832 │ lstm_5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 32)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 16)        │        528 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 16)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1)         │         17 │ dropout_19[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 97,385 (380.41 KB)
#  Trainable params: 96,521 (377.04 KB)
#  Non-trainable params: 864 (3.38 KB)
# Epoch 1/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 228s 105ms/step - loss: 1.0130 - mae: 0.6051 - val_loss: 1.4648 - val_mae: 0.5067 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.6406 - mae: 0.3966 - val_loss: 1.4868 - val_mae: 0.5361 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.5768 - mae: 0.3877 - val_loss: 1.5385 - val_mae: 0.5237 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 104ms/step - loss: 0.5967 - mae: 0.3865 - val_loss: 1.5613 - val_mae: 0.5643 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.6193 - mae: 0.3861 - val_loss: 1.5003 - val_mae: 0.5146 - learning_rate: 0.0010
# Epoch 6/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.5690 - mae: 0.3773 - val_loss: 1.3694 - val_mae: 0.4878 - learning_rate: 0.0010
# Epoch 7/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.5965 - mae: 0.3760 - val_loss: 1.4752 - val_mae: 0.5033 - learning_rate: 0.0010
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 104ms/step - loss: 0.5853 - mae: 0.3787 - val_loss: 1.4611 - val_mae: 0.5112 - learning_rate: 0.0010
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5863 - mae: 0.3789 - val_loss: 1.4594 - val_mae: 0.5155 - learning_rate: 0.0010
# Epoch 10/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5183 - mae: 0.3676 - val_loss: 1.4376 - val_mae: 0.5106 - learning_rate: 5.0000e-04
# Epoch 18/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5435 - mae: 0.3669 - val_loss: 1.4418 - val_mae: 0.5119 - learning_rate: 5.0000e-04
# Epoch 19/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.5611 - mae: 0.3671 - val_loss: 1.5384 - val_mae: 0.5332 - learning_rate: 5.0000e-04
# Epoch 20/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.5188 - mae: 0.3663 - val_loss: 1.5738 - val_mae: 0.5405 - learning_rate: 5.0000e-04
# Epoch 21/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 104ms/step - loss: 0.5545 - mae: 0.3697 - val_loss: 1.5486 - val_mae: 0.5363 - learning_rate: 5.0000e-04
# Epoch 22/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5428 - mae: 0.3682
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 210s 105ms/step - loss: 0.5428 - mae: 0.3682 - val_loss: 1.5098 - val_mae: 0.5229 - learning_rate: 5.0000e-04
# Epoch 23/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.5262 - mae: 0.3645 - val_loss: 1.4849 - val_mae: 0.5171 - learning_rate: 2.5000e-04
# Epoch 24/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5401 - mae: 0.3650 - val_loss: 1.4959 - val_mae: 0.5201 - learning_rate: 2.5000e-04
# Epoch 25/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.4890 - mae: 0.3579 - val_loss: 1.5181 - val_mae: 0.5282 - learning_rate: 2.5000e-04
# Epoch 26/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.4850 - mae: 0.3585 - val_loss: 1.5150 - val_mae: 0.5258 - learning_rate: 2.5000e-04
# Epoch 27/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5072 - mae: 0.3625 - val_loss: 1.5508 - val_mae: 0.5365 - learning_rate: 2.5000e-04
# Epoch 28/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 104ms/step - loss: 0.4978 - mae: 0.3588 - val_loss: 1.4959 - val_mae: 0.5193 - learning_rate: 2.5000e-04
# Epoch 29/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5215 - mae: 0.3663
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5215 - mae: 0.3663 - val_loss: 1.5239 - val_mae: 0.5291 - learning_rate: 2.5000e-04
# Epoch 31/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.5502 - mae: 0.3656 - val_loss: 1.5494 - val_mae: 0.5316 - learning_rate: 1.2500e-04
# Epoch 32/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.4974 - mae: 0.3587 - val_loss: 1.5726 - val_mae: 0.5407 - learning_rate: 1.2500e-04
# Epoch 33/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 105ms/step - loss: 0.5124 - mae: 0.3599 - val_loss: 1.4898 - val_mae: 0.5224 - learning_rate: 1.2500e-04
# Epoch 35/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 210s 105ms/step - loss: 0.5436 - mae: 0.3602 - val_loss: 1.5357 - val_mae: 0.5297 - learning_rate: 1.2500e-04
# Epoch 36/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 210s 105ms/step - loss: 0.5301 - mae: 0.3605 - val_loss: 1.5237 - val_mae: 0.5269 - learning_rate: 1.2500e-04
# Epoch 37/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 105ms/step - loss: 0.5621 - mae: 0.3646 - val_loss: 1.5287 - val_mae: 0.5265 - learning_rate: 1.2500e-04
# Epoch 38/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.5051 - mae: 0.3601
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.5051 - mae: 0.3601 - val_loss: 1.5368 - val_mae: 0.5299 - learning_rate: 1.2500e-04
# Epoch 39/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.4882 - mae: 0.3556 - val_loss: 1.5431 - val_mae: 0.5313 - learning_rate: 6.2500e-05
# Epoch 40/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 218s 109ms/step - loss: 0.5524 - mae: 0.3621 - val_loss: 1.5283 - val_mae: 0.5288 - learning_rate: 6.2500e-05
# Epoch 41/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 218s 109ms/step - loss: 0.4817 - mae: 0.3529 - val_loss: 1.5411 - val_mae: 0.5307 - learning_rate: 6.2500e-05
# Epoch 42/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 104ms/step - loss: 0.5091 - mae: 0.3594 - val_loss: 1.5080 - val_mae: 0.5210 - learning_rate: 6.2500e-05
# Epoch 43/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.4908 - mae: 0.3586 - val_loss: 1.5358 - val_mae: 0.5280 - learning_rate: 6.2500e-05
# Epoch 44/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.4918 - mae: 0.3551 - val_loss: 1.5376 - val_mae: 0.5294 - learning_rate: 6.2500e-05
# Epoch 45/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.4712 - mae: 0.3560 - val_loss: 1.5496 - val_mae: 0.5321 - learning_rate: 6.2500e-05
# Epoch 46/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4917 - mae: 0.3567
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.4917 - mae: 0.3567 - val_loss: 1.5664 - val_mae: 0.5371 - learning_rate: 6.2500e-05
# Epoch 47/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.5163 - mae: 0.3595 - val_loss: 1.5167 - val_mae: 0.5240 - learning_rate: 3.1250e-05
# Epoch 48/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5372 - mae: 0.3578 - val_loss: 1.5434 - val_mae: 0.5303 - learning_rate: 3.1250e-05
# Epoch 49/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 211s 105ms/step - loss: 0.5012 - mae: 0.3576 - val_loss: 1.5230 - val_mae: 0.5250 - learning_rate: 3.1250e-05
# Epoch 50/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.5268 - mae: 0.3593 - val_loss: 1.5674 - val_mae: 0.5363 - learning_rate: 1.5625e-05
# Epoch 56/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.4799 - mae: 0.3553 - val_loss: 1.5378 - val_mae: 0.5291 - learning_rate: 1.5625e-05
# Epoch 57/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 206s 103ms/step - loss: 0.4856 - mae: 0.3566 - val_loss: 1.5425 - val_mae: 0.5300 - learning_rate: 1.5625e-05
# Epoch 58/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.4917 - mae: 0.3559 - val_loss: 1.5318 - val_mae: 0.5280 - learning_rate: 1.5625e-05
# Epoch 59/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.4630 - mae: 0.3540 - val_loss: 1.5461 - val_mae: 0.5313 - learning_rate: 1.5625e-05
# Epoch 60/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.4971 - mae: 0.3560 - val_loss: 1.5189 - val_mae: 0.5255 - learning_rate: 1.5625e-05
# Epoch 61/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 210s 105ms/step - loss: 0.5299 - mae: 0.3584 - val_loss: 1.5314 - val_mae: 0.5279 - learning_rate: 1.5625e-05
# Epoch 62/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.4832 - mae: 0.3563
# Epoch 62: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 104ms/step - loss: 0.4832 - mae: 0.3563 - val_loss: 1.5188 - val_mae: 0.5254 - learning_rate: 1.5625e-05
# Epoch 63/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 105ms/step - loss: 0.5103 - mae: 0.3577 - val_loss: 1.5332 - val_mae: 0.5287 - learning_rate: 7.8125e-06
# Epoch 64/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5161 - mae: 0.3587 - val_loss: 1.5473 - val_mae: 0.5316 - learning_rate: 7.8125e-06
# Epoch 65/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 104ms/step - loss: 0.4970 - mae: 0.3551 - val_loss: 1.5488 - val_mae: 0.5321 - learning_rate: 7.8125e-06
# Epoch 66/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 211s 105ms/step - loss: 0.5066 - mae: 0.3567 - val_loss: 1.5214 - val_mae: 0.5257 - learning_rate: 7.8125e-06
# Epoch 67/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 104ms/step - loss: 0.4859 - mae: 0.3591 - val_loss: 1.5407 - val_mae: 0.5301 - learning_rate: 7.8125e-06
# Epoch 68/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.5102 - mae: 0.3598 - val_loss: 1.5361 - val_mae: 0.5291 - learning_rate: 7.8125e-06
# Epoch 69/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 103ms/step - loss: 0.4779 - mae: 0.3560 - val_loss: 1.5232 - val_mae: 0.5258 - learning_rate: 7.8125e-06
# Epoch 70/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5350 - mae: 0.3583
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 105ms/step - loss: 0.5350 - mae: 0.3583 - val_loss: 1.5638 - val_mae: 0.5351 - learning_rate: 7.8125e-06
# Epoch 71/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 105ms/step - loss: 0.4878 - mae: 0.3551 - val_loss: 1.5644 - val_mae: 0.5351 - learning_rate: 3.9063e-06
# Epoch 72/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 207s 104ms/step - loss: 0.5070 - mae: 0.3599 - val_loss: 1.5556 - val_mae: 0.5334 - learning_rate: 3.9063e-06
# Epoch 73/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 208s 104ms/step - loss: 0.5024 - mae: 0.3591 - val_loss: 1.5359 - val_mae: 0.5287 - learning_rate: 3.9063e-06
# Epoch 74/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 209s 105ms/step - loss: 0.4817 - mae: 0.3545 - val_loss: 1.5514 - val_mae: 0.5327 - learning_rate: 3.9063e-06
# Epoch 75/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 211s 106ms/step - loss: 0.4802 - mae: 0.3546 - val_loss: 1.5478 - val_mae: 0.5315 - learning_rate: 3.9063e-06
# Epoch 76/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 215s 107ms/step - loss: 0.4762 - mae: 0.3527 - val_loss: 1.5427 - val_mae: 0.5308 - learning_rate: 3.9063e-06
# Epoch 77/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 215s 107ms/step - loss: 0.5275 - mae: 0.3594 - val_loss: 1.5573 - val_mae: 0.5340 - learning_rate: 3.9063e-06
# Epoch 78/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.4799 - mae: 0.3528
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 216s 108ms/step - loss: 0.4799 - mae: 0.3528 - val_loss: 1.5537 - val_mae: 0.5331 - learning_rate: 3.9063e-06
# Epoch 79/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 216s 108ms/step - loss: 0.5091 - mae: 0.3558 - val_loss: 1.5605 - val_mae: 0.5349 - learning_rate: 1.9531e-06
# Epoch 80/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 212s 106ms/step - loss: 0.4737 - mae: 0.3549 - val_loss: 1.5766 - val_mae: 0.5383 - learning_rate: 1.9531e-06
# Epoch 81/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 214s 107ms/step - loss: 0.5033 - mae: 0.3601 - val_loss: 1.5507 - val_mae: 0.5322 - learning_rate: 1.9531e-06
# Epoch 82/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 211s 105ms/step - loss: 0.4906 - mae: 0.3572 - val_loss: 1.5164 - val_mae: 0.5247 - learning_rate: 1.9531e-06
# Epoch 83/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 211s 105ms/step - loss: 0.4812 - mae: 0.3583 - val_loss: 1.5547 - val_mae: 0.5330 - learning_rate: 1.9531e-06
# Epoch 84/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 211s 106ms/step - loss: 0.5021 - mae: 0.3568 - val_loss: 1.5367 - val_mae: 0.5291 - learning_rate: 1.9531e-06
# Epoch 85/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 212s 106ms/step - loss: 0.5151 - mae: 0.3586 - val_loss: 1.5441 - val_mae: 0.5310 - learning_rate: 1.9531e-06
# Epoch 86/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4749 - mae: 0.3526
# Epoch 86: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 212s 106ms/step - loss: 0.4749 - mae: 0.3526 - val_loss: 1.5526 - val_mae: 0.5329 - learning_rate: 1.9531e-06
# Epoch 87/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 211s 105ms/step - loss: 0.5004 - mae: 0.3573 - val_loss: 1.5667 - val_mae: 0.5363 - learning_rate: 9.7656e-07
# Epoch 88/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 210s 105ms/step - loss: 0.4706 - mae: 0.3543 - val_loss: 1.5345 - val_mae: 0.5289 - learning_rate: 9.7656e-07
# Epoch 89/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 210s 105ms/step - loss: 0.4850 - mae: 0.3563 - val_loss: 1.5591 - val_mae: 0.5344 - learning_rate: 9.7656e-07
# Epoch 90/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 214s 107ms/step - loss: 0.4717 - mae: 0.3533 - val_loss: 1.5495 - val_mae: 0.5320 - learning_rate: 9.7656e-07
# Epoch 91/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 212s 106ms/step - loss: 0.5314 - mae: 0.3616 - val_loss: 1.5294 - val_mae: 0.5273 - learning_rate: 9.7656e-07
# Epoch 92/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 213s 106ms/step - loss: 0.4790 - mae: 0.3559 - val_loss: 1.5552 - val_mae: 0.5332 - learning_rate: 9.7656e-07
# Epoch 93/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 218s 109ms/step - loss: 0.4918 - mae: 0.3544 - val_loss: 1.5422 - val_mae: 0.5304 - learning_rate: 9.7656e-07
# Epoch 94/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4807 - mae: 0.3544
# Epoch 94: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 218s 109ms/step - loss: 0.4808 - mae: 0.3544 - val_loss: 1.5578 - val_mae: 0.5340 - learning_rate: 9.7656e-07
# Epoch 95/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 215s 107ms/step - loss: 0.4971 - mae: 0.3576 - val_loss: 1.5523 - val_mae: 0.5331 - learning_rate: 4.8828e-07
# Epoch 96/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 214s 107ms/step - loss: 0.5045 - mae: 0.3586 - val_loss: 1.5327 - val_mae: 0.5280 - learning_rate: 4.8828e-07
# Epoch 97/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 212s 106ms/step - loss: 0.5099 - mae: 0.3563 - val_loss: 1.5526 - val_mae: 0.5329 - learning_rate: 4.8828e-07
# Epoch 98/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 214s 107ms/step - loss: 0.5571 - mae: 0.3624 - val_loss: 1.5540 - val_mae: 0.5333 - learning_rate: 4.8828e-07
# Epoch 99/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 214s 107ms/step - loss: 0.4662 - mae: 0.3508 - val_loss: 1.5549 - val_mae: 0.5330 - learning_rate: 4.8828e-07
# Epoch 100/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 214s 107ms/step - loss: 0.4933 - mae: 0.3545 - val_loss: 1.5348 - val_mae: 0.5288 - learning_rate: 4.8828e-07
# Training Performance Metrics:
# MSE: 0.5284
# MAE: 0.3436
# RMSE: 0.7269
# R²: 0.3809
# MAPE: 352.27%
# Test predictions generated successfully!
# Predictions shape: (15996,)
# First 10 predictions: [-0.27586728 -0.29275608 -0.33503136 -0.24578224 -0.20406787 -0.22906607
#  -0.21099333 -0.16966604 -0.22620556 -0.20394473]
# Prediction statistics:
#   Mean: -0.2795
#   Std: 0.1471
#   Min: -0.4526
#   Max: 3.7576

# %%
import os
import math
import random
import numpy as np
import pandas as pd
from typing import List, Dict, Tuple

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class TabDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray = None):
        self.X = X.astype(np.float32)
        self.y = None if y is None else y.astype(np.float32).reshape(-1, 1)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        if self.y is None:
            return torch.from_numpy(self.X[idx])
        return torch.from_numpy(self.X[idx]), torch.from_numpy(self.y[idx])


def prepare_dataframes(train_df: pd.DataFrame,
                       test_df: pd.DataFrame,
                       target_col: str = "Y2",
                       feature_cols: List[str] = None):
    if feature_cols is None:
        letters = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
        cand = letters[:letters.index("N") + 1]  # A..N inclusive
        feature_cols = [c for c in cand if c in train_df.columns]

    if target_col not in train_df.columns:
        raise ValueError(f"Target column '{target_col}' not found in train_df.")

    X_train_raw = train_df[feature_cols].copy()
    y_train_raw = train_df[target_col].copy().values
    X_test_raw  = test_df[feature_cols].copy()
    imputer = SimpleImputer(strategy="median")
    X_train_imp = imputer.fit_transform(X_train_raw)
    X_test_imp  = imputer.transform(X_test_raw)
    x_scaler = StandardScaler()
    X_train_scaled = x_scaler.fit_transform(X_train_imp)
    X_test_scaled  = x_scaler.transform(X_test_imp)
    y_scaler = StandardScaler()
    y_train_scaled = y_scaler.fit_transform(y_train_raw.reshape(-1, 1)).ravel()

    meta = {
        "feature_cols": feature_cols,
        "imputer": imputer,
        "x_scaler": x_scaler,
        "y_scaler": y_scaler
    }
    return X_train_scaled, y_train_scaled, X_test_scaled, meta
class FTTransformerRegressor(nn.Module):
    def __init__(self, n_features: int, d_model: int = 128, n_heads: int = 8,
                 n_layers: int = 3, dropout: float = 0.2):
        super().__init__()
        self.n_features = n_features
        self.d_model = d_model

       
        self.weight = nn.Parameter(torch.randn(n_features, d_model) / math.sqrt(d_model))
        self.bias   = nn.Parameter(torch.zeros(n_features, d_model))
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))
        self.pos_emb   = nn.Parameter(torch.zeros(1, n_features + 1, d_model))
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=n_heads,
            dim_feedforward=4 * d_model,
            dropout=dropout,
            batch_first=True,
            activation='gelu'
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
        self.norm = nn.LayerNorm(d_model)

        # Regression head
        hidden = max(64, d_model // 2)
        self.head = nn.Sequential(
            nn.Linear(d_model, hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, 1)
        )

       
        nn.init.trunc_normal_(self.pos_emb, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, n_features)
        B = x.size(0)

        # Tokenize continuous features: (B, F, 1) * (F, D) + (F, D) -> (B, F, D)
        # Broadcast by aligning dims
        tokens = x.unsqueeze(-1) * self.weight.unsqueeze(0) + self.bias.unsqueeze(0)  # (B, F, D)

        # Prepend [CLS]
        cls = self.cls_token.expand(B, -1, -1)  # (B, 1, D)
        h = torch.cat([cls, tokens], dim=1)     # (B, F+1, D)

        # Add learned positional embedding
        h = h + self.pos_emb[:, :h.size(1), :]

        # Transformer encoder
        h = self.encoder(h)                     # (B, F+1, D)
        cls_out = self.norm(h[:, 0, :])         # (B, D)

        y = self.head(cls_out)                  # (B, 1)
        return y.squeeze(-1)

def train_one_model(model, train_loader, val_loader, epochs, lr, weight_decay,
                    patience=20, verbose=False):
    model = model.to(DEVICE)
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    loss_fn = nn.MSELoss()

    best_val = float('inf')
    best_state = None
    no_improve = 0

    for ep in range(1, epochs + 1):
        model.train()
        train_losses = []
        for xb, yb in train_loader:
            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE).squeeze(-1)
            opt.zero_grad()
            preds = model(xb)
            loss = loss_fn(preds, yb)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            opt.step()
            train_losses.append(loss.item())

        # Validation
        model.eval()
        val_losses = []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(DEVICE)
                yb = yb.to(DEVICE).squeeze(-1)
                preds = model(xb)
                loss = loss_fn(preds, yb)
                val_losses.append(loss.item())
        val_loss = float(np.mean(val_losses))

        if verbose and (ep % 10 == 0 or ep == 1):
            print(f"Epoch {ep:03d} | train MSE={np.mean(train_losses):.4f} | val MSE={val_loss:.4f}")
        if val_loss + 1e-8 < best_val:
            best_val = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            no_improve = 0
        else:
            no_improve += 1
            if no_improve >= patience:
                break
    if best_state is not None:
        model.load_state_dict(best_state)
    return model, best_val


def evaluate(model, loader, y_scaler):
    model.eval()
    preds_list, ys_list = [], []
    with torch.no_grad():
        for batch in loader:
            xb, yb = batch
            xb = xb.to(DEVICE)
            pred_scaled = model(xb).detach().cpu().numpy().ravel()
            preds_list.append(pred_scaled)
            ys_list.append(yb.numpy().ravel())
    preds_scaled = np.concatenate(preds_list)
    ys_scaled = np.concatenate(ys_list)
    preds = y_scaler.inverse_transform(preds_scaled.reshape(-1, 1)).ravel()
    ys    = y_scaler.inverse_transform(ys_scaled.reshape(-1, 1)).ravel()

    r2   = r2_score(ys, preds)
    rmse = math.sqrt(mean_squared_error(ys, preds))
    mae  = mean_absolute_error(ys, preds)
    return {"R2": r2, "RMSE": rmse, "MAE": mae}
def sample_configs(n_features: int, n_trials: int = 14) -> List[Dict]:
    d_models = [64, 128, 256]
    heads    = [4, 8]
    layers   = [2, 3, 4]
    dropouts = [0.1, 0.2, 0.3]
    lrs      = [1e-3, 5e-4]
    wds      = [1e-4, 1e-5]
    batches  = [128, 256]

    all_cfgs = []
    for dm in d_models:
        for nh in heads:
            if dm % nh != 0:
                continue
            for nl in layers:
                for dr in dropouts:
                    for lr in lrs:
                        for wd in wds:
                            for bs in batches:
                                all_cfgs.append({
                                    "d_model": dm,
                                    "n_heads": nh,
                                    "n_layers": nl,
                                    "dropout": dr,
                                    "lr": lr,
                                    "weight_decay": wd,
                                    "batch_size": bs,
                                    "epochs": 300,
                                    "patience": 30
                                })
    random.shuffle(all_cfgs)
    return all_cfgs[:n_trials]

def cv_score(X_scaled, y_scaled, config, n_splits=3, verbose=False):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    r2s = []
    for tr_idx, va_idx in kf.split(X_scaled):
        X_tr, X_va = X_scaled[tr_idx], X_scaled[va_idx]
        y_tr, y_va = y_scaled[tr_idx], y_scaled[va_idx]

        
        train_ds = TabDataset(X_tr, y_tr)
        val_ds   = TabDataset(X_va, y_va)

        train_loader = DataLoader(train_ds, batch_size=config["batch_size"], shuffle=True, num_workers=0)
        val_loader   = DataLoader(val_ds, batch_size=config["batch_size"], shuffle=False, num_workers=0)

        model = FTTransformerRegressor(
            n_features=X_scaled.shape[1],
            d_model=config["d_model"],
            n_heads=config["n_heads"],
            n_layers=config["n_layers"],
            dropout=config["dropout"]
        )
        local_y_scaler = StandardScaler().fit(y_tr.reshape(-1, 1))

        # train
        model, _ = train_one_model(model, train_loader, val_loader,
                                   epochs=config["epochs"], lr=config["lr"],
                                   weight_decay=config["weight_decay"],
                                   patience=config["patience"], verbose=False)

    
        model.eval()
        preds_scaled = []
        with torch.no_grad():
            for xb, _ in val_loader:
                xb = xb.to(DEVICE)
                preds_scaled.append(model(xb).cpu().numpy().ravel())
        preds_scaled = np.concatenate(preds_scaled)
        preds = local_y_scaler.inverse_transform(preds_scaled.reshape(-1, 1)).ravel()
        ys    = local_y_scaler.inverse_transform(y_va.reshape(-1, 1)).ravel()
        r2s.append(r2_score(ys, preds))
    return float(np.mean(r2s))


def tune_hyperparams(X_scaled, y_scaled, n_trials=14, verbose=True):
    best_cfg, best_score = None, -1e9
    for i, cfg in enumerate(sample_configs(X_scaled.shape[1], n_trials=n_trials), 1):
        score = cv_score(X_scaled, y_scaled, cfg, n_splits=3, verbose=False)
        if verbose:
            print(f"[{i:02d}/{n_trials}] CV R2={score:.4f} | cfg={cfg}")
        if score > best_score:
            best_score, best_cfg = score, cfg
    if verbose:
        print(f"\nBest CV R² = {best_score:.4f}\nBest config = {best_cfg}\n")
    return best_cfg, best_score
def fit_and_predict(train_df: pd.DataFrame,
                    test_df: pd.DataFrame,
                    target_col: str = "Y2",
                    feature_cols: List[str] = None,
                    n_trials: int = 14,
                    out_csv: str = "preds.csv",
                    verbose: bool = True) -> Tuple[pd.DataFrame, Dict]:
    
    X_tr, y_tr, X_te, meta = prepare_dataframes(train_df, test_df, target_col, feature_cols)


    best_cfg, _ = tune_hyperparams(X_tr, y_tr, n_trials=n_trials, verbose=verbose)
    X_trn, X_val, y_trn, y_val = train_test_split(X_tr, y_tr, test_size=0.1, random_state=42)
    tr_ds  = TabDataset(X_trn, y_trn)
    va_ds  = TabDataset(X_val, y_val)
    te_ds  = TabDataset(X_te, None)

    train_loader = DataLoader(tr_ds, batch_size=best_cfg["batch_size"], shuffle=True, num_workers=0)
    val_loader   = DataLoader(va_ds, batch_size=best_cfg["batch_size"], shuffle=False, num_workers=0)
    test_loader  = DataLoader(te_ds, batch_size=best_cfg["batch_size"], shuffle=False, num_workers=0)

   
    model = FTTransformerRegressor(
        n_features=X_tr.shape[1],
        d_model=best_cfg["d_model"],
        n_heads=best_cfg["n_heads"],
        n_layers=best_cfg["n_layers"],
        dropout=best_cfg["dropout"]
    ).to(DEVICE)

    model, _ = train_one_model(
        model, train_loader, val_loader,
        epochs=best_cfg["epochs"],
        lr=best_cfg["lr"],
        weight_decay=best_cfg["weight_decay"],
        patience=best_cfg["patience"],
        verbose=verbose
    )
    y_scaler = meta["y_scaler"]
    tr_full_loader = DataLoader(TabDataset(X_tr, y_tr), batch_size=best_cfg["batch_size"], shuffle=False)

    train_metrics = evaluate(model, tr_full_loader, y_scaler)
    val_metrics   = evaluate(model, val_loader, y_scaler)

    if verbose:
        print(f"\nFinal (refit) TRAIN  -> R2={train_metrics['R2']:.4f}, RMSE={train_metrics['RMSE']:.4f}, MAE={train_metrics['MAE']:.4f}")
        print(f"Final (refit) VAL    -> R2={val_metrics['R2']:.4f}, RMSE={val_metrics['RMSE']:.4f}, MAE={val_metrics['MAE']:.4f}")


    model.eval()
    preds_scaled = []
    with torch.no_grad():
        for xb in test_loader:
            xb = xb.to(DEVICE)
            preds_scaled.append(model(xb).cpu().numpy().ravel())
    preds_scaled = np.concatenate(preds_scaled)
    preds = y_scaler.inverse_transform(preds_scaled.reshape(-1, 1)).ravel()

    out = pd.DataFrame({"Y2": preds}, index=test_df.index)
    out.to_csv(out_csv, index=True)
    if verbose:
        print(f"\nSaved predictions to: {os.path.abspath(out_csv)}")

    return out, {
        "best_config": best_cfg,
        "train_metrics": train_metrics,
        "val_metrics": val_metrics,
        "feature_cols": meta["feature_cols"]
    }
train = pd.read_csv("/kaggle/input/quantc/train.csv")
test = pd.read_csv("/kaggle/input/quantc/test.csv")
preds, info = fit_and_predict(train, test, target_col="Y2", feature_cols=None, n_trials=10)
